# %%
import matplotlib.pyplot as plt
import numpy as np
import SimpleITK as sitk
import os as os
import nrrd as reader

# %%
def join(one, two):
    return os.path.join(one, two)

# %%
def check_path(path):
    count=0
    for files in sorted(os.listdir(path)):
        image_path = os.path.join(path,files)
        count+=1
    return count

# %%
# (patient count* 15) check_path function will return total patient count 
folder_path = join(os.getcwd(), "Incoming Annotations")

length = check_path(folder_path)
inputs = np.zeros((length*15,256,512,1))
outputs = np.zeros((length*15,256,512,1 ))

# %%
def dcm_to_np(path):
    global dic_count
    try:
        slice_filenames = sitk.ImageSeriesReader_GetGDCMSeriesFileNames(path)
        image = sitk.ReadImage(slice_filenames)
        for x in range(15):
            current_slice = image[:, :, x]
            current_array = sitk.GetArrayFromImage(current_slice)
            inputs[dic_count] = current_array[:, :, np.newaxis]
            dic_count+=1
        print(dic_count)
    except Exception as e:
        print(e)
#         print("Problem with this folder -> " + path)

# %%
def nrrd_to_np(meta_object):
    global ann_count
    try:
        data = sitk.GetArrayFromImage(meta_object)
        for p in range(15):
            current_seg = data[p, :, :]
            outputs[ann_count] = current_seg[:, :, np.newaxis]
            ann_count+=1
        print(ann_count)
    except Exception as e:
        print(e)

# %%
dic_count = 0
ann_count = 0

try:
    for patient in sorted(os.listdir(folder_path)):
            patient_path = join(folder_path, patient)
            nrrd_folder = join(patient_path, "NRRD")
            dcm_to_np(patient_path)
            for nrrd in os.listdir(nrrd_folder):
                if(".nrrd" in nrrd):
                    segmentation = sitk.ReadImage(join(nrrd_folder, nrrd))
                    nrrd_to_np(segmentation)
except Exception as e:
    print(e)
# Out:
# 15
# 15
# 30
# 30
# 45
# 45
# 60
# 60
# 75
# 75
# 90
# 90
# 105
# 105
# 120
# 120
# 135
# 135
# 150
# 150
# 165
# 165
# 180
# 180
# 195
# 195
# 210
# 210
# 225
# 225
# 240
# 240
# 255
# 255
# 270
# 270
# 285
# 285
# 300
# 300
# 315
# 315
# 330
# 330
# 345
# 345
# 360
# 360
# 375
# 375
# 390
# 390
# 405
# 405
# 420
# 420
# 435
# 435
# 450
# 450
# 465
# 465
# 480
# 480
# 495
# 495
# 510
# 510
# 525
# 525
# 540
# 540
# 555
# 555
# 570
# 570
# 585
# 585
# 600
# 600
# 615
# 615
# 630
# 630
# 645
# 645
# 660
# 660
# 675
# 675
# 690
# 690
# 705
# 705
# 720
# 720
# 735
# 735
# 750
# 750
# 765
# 765
# 780
# 780
# 795
# 795
# 810
# 810
# 825
# 825
# 840
# 840
# 855
# 855
# 870
# 870
# 885
# 885
# 900
# 900
# 915
# 915
# 930
# 930
# 945
# 945
# 960
# 960
# 975
# 975
# 990
# 990
# 1005
# 1005
# 1020
# 1020
# 1035
# 1035
# 1050
# 1050
# 1065
# 1065
# 1080
# 1080
# 1095
# 1095
# 1110
# 1110
# 1125
# 1125
# 1140
# 1140
# 1155
# 1155
# 1170
# 1170
# 1185
# 1185
# 1200
# 1200
# 1215
# 1215
# 1230
# 1230
# 1245
# 1245
# 1260
# 1260
# 1275
# 1275
# 1290
# 1290
# 1305
# 1305
# 1320
# 1320
# 1335
# 1335
# 1350
# 1350
# 1365
# 1365
# 1380
# 1380
# 1395
# 1395
# 1410
# 1410
# 1425
# 1425
# 1440
# 1440
# 1455
# 1455
# 1470
# 1470
# 1485
# 1485
# 1500
# 1500
# 1515
# 1515
# 1530
# 1530
# 1545
# 1545
# 1560
# 1560
# 1575
# 1575
# 1590
# 1590
# 1605
# 1605
# 1620
# 1620
# 1635
# 1635
# 1650
# 1650
# 1665
# 1665
# 1680
# 1680
# 1695
# 1695
# 1710
# 1710
# 1725
# 1725
# 1740
# 1740
# 1755
# 1755

# %%
for i in range(1500, 1515):
    plt.imshow(inputs[i].reshape(256, 512), cmap=plt.cm.bone)
    plt.imshow(outputs[i][:, :, 0], alpha=0.5)
    plt.show()

# %%
# import sklearn.preprocessing as sk
# scaler = sk.MinMaxScaler(feature_range=(0, 255))
# inputs = scaler.fit_transform(inputs.flatten().reshape(-1, 1))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-d8452a35aa9c> in <module>
# ----> 1 import sklearn.preprocessing as sk
#       2 scaler = sk.MinMaxScaler(feature_range=(0, 255))
#       3 inputs = scaler.fit_transform(inputs.flatten().reshape(-1, 1))
#
# /usr/lib/python3/dist-packages/sklearn/preprocessing/__init__.py in <module>
#      29 from .label import MultiLabelBinarizer
#      30
# ---> 31 from .imputation import Imputer
#      32
#      33
#
# /usr/lib/python3/dist-packages/sklearn/preprocessing/imputation.py in <module>
#       7 import numpy.ma as ma
#       8 from scipy import sparse
# ----> 9 from scipy import stats
#      10
#      11 from ..base import BaseEstimator, TransformerMixin
#
# /usr/lib/python3/dist-packages/scipy/stats/__init__.py in <module>
#     338 from .stats import *
#     339 from .distributions import *
# --> 340 from .morestats import *
#     341 from ._binned_statistic import *
#     342 from .kde import gaussian_kde
#
# /usr/lib/python3/dist-packages/scipy/stats/morestats.py in <module>
#      14                    sqrt, ceil, floor, array, poly1d, compress,
#      15                    pi, exp, ravel, angle, count_nonzero)
# ---> 16 from numpy.testing.decorators import setastest
#      17
#      18 from scipy._lib.six import string_types
#
# ImportError: No module named 'numpy.testing.decorators'

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *

def unet_model(im_height, im_width, im_chan):

    input_img = Input((im_height, im_width, im_chan,), name='img')

    inp = BatchNormalization()(input_img)

    c1 = Conv2D(4, (3, 3), activation='relu', padding='same') (inp)
    a1 = MaxPooling2D((2, 2))(c1)
    c1 = Dropout(0.2)(c1)
    c1 = Conv2D(4, (3, 3), activation='relu', padding='same') (c1)
    p1 = MaxPooling2D((2, 2)) (c1)

    cat1 = concatenate([p1, a1])

    c2 = Conv2D(8, (3, 3), activation='relu', padding='same') (cat1)
    a2 = MaxPooling2D((2, 2))(c2)
    c2 = Dropout(0.2)(c2)
    c2 = Conv2D(8, (3, 3), activation='relu', padding='same') (c2)
    p2 = MaxPooling2D((2, 2)) (c2)

    cat2 = concatenate([p2, a2])

    c3 = Conv2D(16, (3, 3), activation='relu', padding='same') (cat2)
    a3 = MaxPooling2D((2, 2))(c3)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(16, (3, 3), activation='relu', padding='same') (c3)
    p3 = MaxPooling2D((2, 2)) (c3)

    cat3 = concatenate([p3, a3])

    c4 = Conv2D(32, (3, 3), activation='relu', padding='same') (cat3)
    a4 = MaxPooling2D((2, 2))(c4)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(32, (3, 3), activation='relu', padding='same') (c4)
    p4 = MaxPooling2D((2, 2)) (c4)

    cat4 = concatenate([p4, a4])

    c5 = Conv2D(64, (3, 3), activation='relu', padding='same') (cat4)
    a5 = MaxPooling2D((2, 2))(c5)
    c5 = Dropout(0.2)(c5)
    c5 = Conv2D(64, (3, 3), activation='relu', padding='same') (c5)
    p5 = MaxPooling2D((2, 2)) (c5)

    cat5 = concatenate([p5, a5])

    c6 = Conv2D(128, (3, 3), activation='relu', padding='same') (cat5)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same') (c6)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c5])
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same') (u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same') (c7)

    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c4])
    c8 = Conv2D(32, (3, 3), activation='relu', padding='same') (u8)
    c8 = Dropout(0.2)(c8)
    c8 = Conv2D(32, (3, 3), activation='relu', padding='same') (c8)

    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c3])
    c9 = Conv2D(16, (3, 3), activation='relu', padding='same') (u9)
    c9 = Dropout(0.2)(c9)
    c9 = Conv2D(16, (3, 3), activation='relu', padding='same') (c9)

    u10 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same') (c9)
    u10 = concatenate([u10, c2])
    c10 = Conv2D(8, (3, 3), activation='relu', padding='same') (u10)
    c10 = Dropout(0.2)(c10)
    c10 = Conv2D(8, (3, 3), activation='relu', padding='same') (c10)

    u11 = Conv2DTranspose(4, (2, 2), strides=(2, 2), padding='same') (c10)
    u11 = concatenate([u11, c1], axis = 3)
    c11 = Conv2D(4, (3, 3), activation='relu', padding='same') (u11)
    c11 = Dropout(0.2)(c11)
    c11 = Conv2D(4, (3, 3), activation='relu', padding='same') (c11)

    outputs = Conv2D(1, (1, 1), activation='sigmoid') (c11)

    model = Model(inputs=[input_img], outputs=[outputs])

    return model
model = unet_model(256, 512, 1)
model.summary()
# Out:
# /usr/lib/python3/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/lib/python3/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/lib/python3/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/lib/python3/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/lib/python3/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/lib/python3/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                (None, 256, 512, 1)  0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 512, 1)  4           img[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 512, 4)  40          batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256, 512, 4)  0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 512, 4)  148         dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 256, 4)  0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 256, 4)  0           conv2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 128, 256, 8)  0           max_pooling2d_1[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 256, 8)  584         concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128, 256, 8)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 256, 8)  584         dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 64, 128, 8)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 128, 8)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 128, 16)  0           max_pooling2d_3[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 128, 16)  2320        concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64, 128, 16)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 128, 16)  2320        dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 32, 64, 16)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 32, 64, 16)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 64, 32)   0           max_pooling2d_5[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 64, 32)   9248        concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32, 64, 32)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 64, 32)   9248        dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 16, 32, 32)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 16, 32, 32)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 32, 64)   0           max_pooling2d_7[0][0]
#                                                                  max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 32, 64)   36928       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16, 32, 64)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 32, 64)   36928       dropout_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 8, 16, 64)    0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 8, 16, 64)    0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 8, 16, 128)   0           max_pooling2d_9[0][0]
#                                                                  max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 16, 128)   147584      concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 8, 16, 128)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 16, 128)   147584      dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 32, 64)   32832       conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 16, 32, 128)  0           conv2d_transpose[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 32, 64)   73792       concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 32, 64)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 32, 64)   36928       dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 64, 32)   8224        conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 32, 64, 64)   0           conv2d_transpose_1[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 64, 32)   18464       concatenate_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 32, 64, 32)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 64, 32)   9248        dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 128, 16)  2064        conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 64, 128, 32)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 128, 16)  4624        concatenate_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 64, 128, 16)  0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 128, 16)  2320        dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 256, 8)  520         conv2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 128, 256, 16) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 256, 8)  1160        concatenate_8[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 128, 256, 8)  0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 256, 8)  584         dropout_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 256, 512, 4)  132         conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 256, 512, 8)  0           conv2d_transpose_4[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 512, 4)  292         concatenate_9[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 256, 512, 4)  0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 512, 4)  148         dropout_10[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 512, 1)  5           conv2d_21[0][0]
# ==================================================================================================
# Total params: 584,857
# Trainable params: 584,855
# Non-trainable params: 2
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss="binary_crossentropy", metrics=["binary_crossentropy"])
results = model.fit(x=inputs, y=outputs, epochs=60, batch_size=8)
# Out:
# Epoch 1/60
# 1755/1755 [==============================] - 19s 11ms/step - loss: -21.1150 - binary_crossentropy: -2.6453
# Epoch 2/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -35.3132 - binary_crossentropy: -4.4188
# Epoch 3/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -35.6624 - binary_crossentropy: -4.4619
# Epoch 4/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.0541 - binary_crossentropy: -4.5134
# Epoch 5/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.1729 - binary_crossentropy: -4.5280
# Epoch 6/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.0117 - binary_crossentropy: -4.5056
# Epoch 7/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.1600 - binary_crossentropy: -4.5252
# Epoch 8/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.2955 - binary_crossentropy: -4.5411
# Epoch 9/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.3145 - binary_crossentropy: -4.5448
# Epoch 10/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.3441 - binary_crossentropy: -4.5474
# Epoch 11/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.2730 - binary_crossentropy: -4.5398
# Epoch 12/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.2648 - binary_crossentropy: -4.5407
# Epoch 13/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.3808 - binary_crossentropy: -4.5522
# Epoch 14/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.3962 - binary_crossentropy: -4.5544
# Epoch 15/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.3977 - binary_crossentropy: -4.5547
# Epoch 16/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.4219 - binary_crossentropy: -4.5569
# Epoch 17/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -35.7520 - binary_crossentropy: -4.4751
# Epoch 18/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.3568 - binary_crossentropy: -4.5484
# Epoch 19/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.3623 - binary_crossentropy: -4.5504
# Epoch 20/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.3821 - binary_crossentropy: -4.5539
# Epoch 21/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.4230 - binary_crossentropy: -4.5583
# Epoch 22/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.4452 - binary_crossentropy: -4.5616
# Epoch 23/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.4835 - binary_crossentropy: -4.5650
# Epoch 24/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.4861 - binary_crossentropy: -4.5665
# Epoch 25/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.5028 - binary_crossentropy: -4.5701
# Epoch 26/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.5416 - binary_crossentropy: -4.5717
# Epoch 27/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.2504 - binary_crossentropy: -4.5369
# Epoch 28/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.3229 - binary_crossentropy: -4.5460
# Epoch 29/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.4751 - binary_crossentropy: -4.5630
# Epoch 30/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.4435 - binary_crossentropy: -4.5598
# Epoch 31/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.5083 - binary_crossentropy: -4.5679
# Epoch 32/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.5425 - binary_crossentropy: -4.5732
# Epoch 33/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.5582 - binary_crossentropy: -4.5757
# Epoch 34/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.5634 - binary_crossentropy: -4.5748
# Epoch 35/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.5881 - binary_crossentropy: -4.5773
# Epoch 36/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.5925 - binary_crossentropy: -4.5788
# Epoch 37/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.6079 - binary_crossentropy: -4.5799
# Epoch 38/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.5964 - binary_crossentropy: -4.5814
# Epoch 39/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.6248 - binary_crossentropy: -4.5825
# Epoch 40/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.6125 - binary_crossentropy: -4.5832
# Epoch 41/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.6351 - binary_crossentropy: -4.5836
# Epoch 42/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.6270 - binary_crossentropy: -4.5832
# Epoch 43/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.4266 - binary_crossentropy: -4.5583
# Epoch 44/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.1632 - binary_crossentropy: -4.5248
# Epoch 45/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.4583 - binary_crossentropy: -4.5612
# Epoch 46/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.5249 - binary_crossentropy: -4.5722
# Epoch 47/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.5693 - binary_crossentropy: -4.5765
# Epoch 48/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.5985 - binary_crossentropy: -4.5794
# Epoch 49/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.6038 - binary_crossentropy: -4.5816
# Epoch 50/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.6408 - binary_crossentropy: -4.5844
# Epoch 51/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.6331 - binary_crossentropy: -4.5838
# Epoch 52/60
# 1755/1755 [==============================] - 12s 7ms/step - loss: -36.6476 - binary_crossentropy: -4.5856
# Epoch 53/60
#  528/1755 [========>.....................] - ETA: 8s - loss: -36.8426 - binary_crossentropy: -4.6053

# %%
plt.title("Metrics")
plt.plot(results.history["loss"], label="loss")
plt.xlabel("Epochs")
plt.legend()

# %%
result = model.predict(inputs[100].reshape(1, 256, 512, 1))
plt.imshow(inputs[100].reshape(256, 512), cmap=plt.cm.bone)
plt.show()
plt.imshow(result[0][:, :, 3])
plt.show()
