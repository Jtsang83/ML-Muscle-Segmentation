# %%
import matplotlib.pyplot as plt
import numpy as np
import SimpleITK as sitk
import os as os
import nrrd as reader

# %%
def join(one, two):
    return os.path.join(one, two)

# %%
def check_path(path):
    count=0
    for files in sorted(os.listdir(path)):
        image_path = os.path.join(path,files)
        count+=1
    return count

# %%
# (patient count* 15) check_path function will return total patient count 
folder_path = join(os.getcwd(), "Incoming Annotations")

length = check_path(folder_path)
inputs = np.zeros((length*15,256,512, 1))
outputs = np.zeros((length*15,256,512 , 9))

# %%
def dcm_to_np(path):
    global dic_count
    try:
        slice_filenames = sitk.ImageSeriesReader_GetGDCMSeriesFileNames(path)
        image = sitk.ReadImage(slice_filenames)
        for x in range(15):
            current_slice = image[:, :, x]
            current_array = sitk.GetArrayFromImage(current_slice)
            inputs[dic_count] = current_array[:, :, np.newaxis]
            dic_count+=1
        print(dic_count)
    except Exception as e:
        print(e)
#         print("Problem with this folder -> " + path)

# %%
def nrrd_to_np(meta_object):
    global ann_count
    try:
        data = sitk.GetArrayFromImage(meta_object)
        for p in range(15):
            current_seg = data[p, :, :]
            black = np.zeros([256, 512, 9])
            for y, a in enumerate(current_seg):
                for x, b in enumerate(a):
                    if b>0:
                        black[y][x][b-1] = 1
            outputs[ann_count] = black
            ann_count+=1
        print(ann_count)
    except Exception as e:
        print(e)

# %%
dic_count = 0
ann_count = 0

try:
    for patient in sorted(os.listdir(folder_path)):
            patient_path = join(folder_path, patient)
            nrrd_folder = join(patient_path, "NRRD")
            dcm_to_np(patient_path)
            for nrrd in os.listdir(nrrd_folder):
                if(".nrrd" in nrrd):
                    segmentation = sitk.ReadImage(join(nrrd_folder, nrrd))
                    nrrd_to_np(segmentation)
except Exception as e:
    print(e)
# Out:
# 15
# 15
# 30
# 30
# 45
# 45
# 60
# 60
# 75
# 75
# 90
# 90
# 105
# 105
# 120
# 120
# 135
# 135
# 150
# 150
# 165
# 165
# 180
# 180
# 195
# 195
# 210
# 210
# 225
# 225
# 240
# 240
# 255
# 255
# 270
# 270
# 285
# 285
# 300
# 300
# 315
# 315
# 330
# 330
# 345
# 345
# 360
# 360
# 375
# 375
# 390
# 390
# 405
# 405
# 420
# 420
# 435
# 435
# 450
# 450
# 465
# 465
# 480
# 480
# 495
# 495
# 510
# 510
# 525
# 525
# 540
# 540
# 555
# 555
# 570
# 570
# 585
# 585
# 600
# 600
# 615
# 615
# 630
# 630
# 645
# 645
# 660
# 660
# 675
# 675
# 690
# 690
# 705
# 705
# 720
# 720
# 735
# 735
# 750
# 750
# 765
# 765
# 780
# 780
# 795
# 795
# 810
# 810
# 825
# 825
# 840
# 840
# 855
# 855
# 870
# 870
# 885
# 885
# 900
# 900
# 915
# 915
# 930
# 930
# 945
# 945
# 960
# 960
# 975
# 975
# 990
# 990
# 1005
# 1005
# 1020
# 1020
# 1035
# 1035
# 1050
# 1050
# 1065
# 1065
# 1080
# 1080
# 1095
# 1095
# 1110
# 1110
# 1125
# 1125
# 1140
# 1140
# 1155
# 1155
# 1170
# 1170
# 1185
# 1185
# 1200
# 1200
# 1215
# 1215
# 1230
# 1230
# 1245
# 1245
# 1260
# 1260
# 1275
# 1275
# 1290
# 1290
# 1305
# 1305
# 1320
# 1320
# 1335
# 1335
# 1350
# 1350
# 1365
# 1365
# 1380
# 1380
# 1395
# 1395
# 1410
# 1410
# 1425
# 1425
# 1440
# 1440
# 1455
# 1455
# 1470
# 1470
# 1485
# 1485
# 1500
# 1500
# 1515
# 1515
# 1530
# 1530
# 1545
# 1545
# 1560
# 1560
# 1575
# 1575
# 1590
# 1590
# 1605
# 1605
# 1620
# 1620
# 1635
# 1635
# 1650
# 1650
# 1665
# 1665
# 1680
# 1680
# 1695
# 1695
# 1710
# 1710
# 1725
# 1725
# 1740
# 1740
# 1755
# 1755

# %%
for i in range(1500, 1515):
    plt.imshow(inputs[i].reshape(256, 512), cmap=plt.cm.bone)
    plt.imshow(outputs[i][:, :, 0], alpha=0.5)
    plt.show()

# %%
# import sklearn.preprocessing as sk
# scaler = sk.MinMaxScaler(feature_range=(0, 255))
# inputs = scaler.fit_transform(inputs.flatten().reshape(-1, 1))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-d8452a35aa9c> in <module>
# ----> 1 import sklearn.preprocessing as sk
#       2 scaler = sk.MinMaxScaler(feature_range=(0, 255))
#       3 inputs = scaler.fit_transform(inputs.flatten().reshape(-1, 1))
#
# /usr/lib/python3/dist-packages/sklearn/preprocessing/__init__.py in <module>
#      29 from .label import MultiLabelBinarizer
#      30
# ---> 31 from .imputation import Imputer
#      32
#      33
#
# /usr/lib/python3/dist-packages/sklearn/preprocessing/imputation.py in <module>
#       7 import numpy.ma as ma
#       8 from scipy import sparse
# ----> 9 from scipy import stats
#      10
#      11 from ..base import BaseEstimator, TransformerMixin
#
# /usr/lib/python3/dist-packages/scipy/stats/__init__.py in <module>
#     338 from .stats import *
#     339 from .distributions import *
# --> 340 from .morestats import *
#     341 from ._binned_statistic import *
#     342 from .kde import gaussian_kde
#
# /usr/lib/python3/dist-packages/scipy/stats/morestats.py in <module>
#      14                    sqrt, ceil, floor, array, poly1d, compress,
#      15                    pi, exp, ravel, angle, count_nonzero)
# ---> 16 from numpy.testing.decorators import setastest
#      17
#      18 from scipy._lib.six import string_types
#
# ImportError: No module named 'numpy.testing.decorators'

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *

def unet_model(im_height, im_width, im_chan):

    input_img = Input((im_height, im_width, im_chan,), name='img')

    inp = BatchNormalization()(input_img)

    c1 = Conv2D(4, (3, 3), activation='relu', padding='same') (inp)
    a1 = MaxPooling2D((2, 2))(c1)
    c1 = Dropout(0.2)(c1)
    c1 = Conv2D(4, (3, 3), activation='relu', padding='same') (c1)
    p1 = MaxPooling2D((2, 2)) (c1)

    cat1 = concatenate([p1, a1])

    c2 = Conv2D(8, (3, 3), activation='relu', padding='same') (cat1)
    a2 = MaxPooling2D((2, 2))(c2)
    c2 = Dropout(0.2)(c2)
    c2 = Conv2D(8, (3, 3), activation='relu', padding='same') (c2)
    p2 = MaxPooling2D((2, 2)) (c2)

    cat2 = concatenate([p2, a2])

    c3 = Conv2D(16, (3, 3), activation='relu', padding='same') (cat2)
    a3 = MaxPooling2D((2, 2))(c3)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(16, (3, 3), activation='relu', padding='same') (c3)
    p3 = MaxPooling2D((2, 2)) (c3)

    cat3 = concatenate([p3, a3])

    c4 = Conv2D(32, (3, 3), activation='relu', padding='same') (cat3)
    a4 = MaxPooling2D((2, 2))(c4)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(32, (3, 3), activation='relu', padding='same') (c4)
    p4 = MaxPooling2D((2, 2)) (c4)

    cat4 = concatenate([p4, a4])

    c5 = Conv2D(64, (3, 3), activation='relu', padding='same') (cat4)
    a5 = MaxPooling2D((2, 2))(c5)
    c5 = Dropout(0.2)(c5)
    c5 = Conv2D(64, (3, 3), activation='relu', padding='same') (c5)
    p5 = MaxPooling2D((2, 2)) (c5)

    cat5 = concatenate([p5, a5])

    c6 = Conv2D(128, (3, 3), activation='relu', padding='same') (cat5)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same') (c6)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c5])
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same') (u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same') (c7)

    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c4])
    c8 = Conv2D(32, (3, 3), activation='relu', padding='same') (u8)
    c8 = Dropout(0.2)(c8)
    c8 = Conv2D(32, (3, 3), activation='relu', padding='same') (c8)

    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c3])
    c9 = Conv2D(16, (3, 3), activation='relu', padding='same') (u9)
    c9 = Dropout(0.2)(c9)
    c9 = Conv2D(16, (3, 3), activation='relu', padding='same') (c9)

    u10 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same') (c9)
    u10 = concatenate([u10, c2])
    c10 = Conv2D(8, (3, 3), activation='relu', padding='same') (u10)
    c10 = Dropout(0.2)(c10)
    c10 = Conv2D(8, (3, 3), activation='relu', padding='same') (c10)

    u11 = Conv2DTranspose(4, (2, 2), strides=(2, 2), padding='same') (c10)
    u11 = concatenate([u11, c1], axis = 3)
    c11 = Conv2D(4, (3, 3), activation='relu', padding='same') (u11)
    c11 = Dropout(0.2)(c11)
    c11 = Conv2D(4, (3, 3), activation='relu', padding='same') (c11)

    outputs = Conv2D(9, (1, 1), activation='softmax') (c11)

    model = Model(inputs=[input_img], outputs=[outputs])

    return model
model = unet_model(256, 512, 1)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                (None, 256, 512, 1)  0
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 256, 512, 1)  4           img[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 256, 512, 4)  40          batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 256, 512, 4)  0           conv2d_69[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 256, 512, 4)  148         dropout_33[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_31 (MaxPooling2D) (None, 128, 256, 4)  0           conv2d_70[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_30 (MaxPooling2D) (None, 128, 256, 4)  0           conv2d_69[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 128, 256, 8)  0           max_pooling2d_31[0][0]
#                                                                  max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 128, 256, 8)  584         concatenate_30[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 128, 256, 8)  0           conv2d_71[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 128, 256, 8)  584         dropout_34[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_33 (MaxPooling2D) (None, 64, 128, 8)   0           conv2d_72[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_32 (MaxPooling2D) (None, 64, 128, 8)   0           conv2d_71[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 64, 128, 16)  0           max_pooling2d_33[0][0]
#                                                                  max_pooling2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 64, 128, 16)  2320        concatenate_31[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 64, 128, 16)  0           conv2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 64, 128, 16)  2320        dropout_35[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_35 (MaxPooling2D) (None, 32, 64, 16)   0           conv2d_74[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_34 (MaxPooling2D) (None, 32, 64, 16)   0           conv2d_73[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 32, 64, 32)   0           max_pooling2d_35[0][0]
#                                                                  max_pooling2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 32, 64, 32)   9248        concatenate_32[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 32, 64, 32)   0           conv2d_75[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 32, 64, 32)   9248        dropout_36[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_37 (MaxPooling2D) (None, 16, 32, 32)   0           conv2d_76[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_36 (MaxPooling2D) (None, 16, 32, 32)   0           conv2d_75[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 16, 32, 64)   0           max_pooling2d_37[0][0]
#                                                                  max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 16, 32, 64)   36928       concatenate_33[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 16, 32, 64)   0           conv2d_77[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 16, 32, 64)   36928       dropout_37[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_39 (MaxPooling2D) (None, 8, 16, 64)    0           conv2d_78[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_38 (MaxPooling2D) (None, 8, 16, 64)    0           conv2d_77[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 8, 16, 128)   0           max_pooling2d_39[0][0]
#                                                                  max_pooling2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 16, 128)   147584      concatenate_34[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 8, 16, 128)   0           conv2d_79[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 16, 128)   147584      dropout_38[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_15 (Conv2DTran (None, 16, 32, 64)   32832       conv2d_80[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 16, 32, 128)  0           conv2d_transpose_15[0][0]
#                                                                  conv2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 16, 32, 64)   73792       concatenate_35[0][0]
# __________________________________________________________________________________________________
# dropout_39 (Dropout)            (None, 16, 32, 64)   0           conv2d_81[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 16, 32, 64)   36928       dropout_39[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_16 (Conv2DTran (None, 32, 64, 32)   8224        conv2d_82[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 32, 64, 64)   0           conv2d_transpose_16[0][0]
#                                                                  conv2d_76[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 32, 64, 32)   18464       concatenate_36[0][0]
# __________________________________________________________________________________________________
# dropout_40 (Dropout)            (None, 32, 64, 32)   0           conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 32, 64, 32)   9248        dropout_40[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_17 (Conv2DTran (None, 64, 128, 16)  2064        conv2d_84[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 64, 128, 32)  0           conv2d_transpose_17[0][0]
#                                                                  conv2d_74[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 64, 128, 16)  4624        concatenate_37[0][0]
# __________________________________________________________________________________________________
# dropout_41 (Dropout)            (None, 64, 128, 16)  0           conv2d_85[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 64, 128, 16)  2320        dropout_41[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_18 (Conv2DTran (None, 128, 256, 8)  520         conv2d_86[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 128, 256, 16) 0           conv2d_transpose_18[0][0]
#                                                                  conv2d_72[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 128, 256, 8)  1160        concatenate_38[0][0]
# __________________________________________________________________________________________________
# dropout_42 (Dropout)            (None, 128, 256, 8)  0           conv2d_87[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 128, 256, 8)  584         dropout_42[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_19 (Conv2DTran (None, 256, 512, 4)  132         conv2d_88[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 256, 512, 8)  0           conv2d_transpose_19[0][0]
#                                                                  conv2d_70[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 256, 512, 4)  292         concatenate_39[0][0]
# __________________________________________________________________________________________________
# dropout_43 (Dropout)            (None, 256, 512, 4)  0           conv2d_89[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 256, 512, 4)  148         dropout_43[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 256, 512, 9)  45          conv2d_90[0][0]
# ==================================================================================================
# Total params: 584,897
# Trainable params: 584,895
# Non-trainable params: 2
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=["accuracy"])
results = model.fit(x=inputs, y=outputs, epochs=60, batch_size=8)
# Out:
# Epoch 1/60
# 1770/1770 [==============================] - 92s 52ms/step - loss: 1.1874 - acc: 0.0253
# Epoch 2/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.6543 - acc: 0.0575
# Epoch 3/60
# 1770/1770 [==============================] - 81s 45ms/step - loss: 0.4080 - acc: 0.0657
# Epoch 4/60
# 1770/1770 [==============================] - 81s 45ms/step - loss: 0.3153 - acc: 0.0688
# Epoch 5/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.2214 - acc: 0.0789
# Epoch 6/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.1886 - acc: 0.0929
# Epoch 7/60
# 1770/1770 [==============================] - 81s 45ms/step - loss: 0.1586 - acc: 0.1023
# Epoch 8/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.1336 - acc: 0.1171
# Epoch 9/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.1121 - acc: 0.1457
# Epoch 10/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0974 - acc: 0.1675
# Epoch 11/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.0886 - acc: 0.1653
# Epoch 12/60
# 1770/1770 [==============================] - 81s 45ms/step - loss: 0.0798 - acc: 0.1865
# Epoch 13/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.0757 - acc: 0.1679
# Epoch 14/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.0686 - acc: 0.1649
# Epoch 15/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.0651 - acc: 0.1703
# Epoch 16/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.0646 - acc: 0.2068
# Epoch 17/60
# 1770/1770 [==============================] - 81s 45ms/step - loss: 0.0569 - acc: 0.1982
# Epoch 18/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0598 - acc: 0.1869
# Epoch 19/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0524 - acc: 0.1787
# Epoch 20/60
# 1770/1770 [==============================] - 81s 45ms/step - loss: 0.0530 - acc: 0.1824
# Epoch 21/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0485 - acc: 0.1592
# Epoch 22/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0497 - acc: 0.1415
# Epoch 23/60
# 1770/1770 [==============================] - 81s 45ms/step - loss: 0.0458 - acc: 0.1596
# Epoch 24/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0477 - acc: 0.1682
# Epoch 25/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0510 - acc: 0.1458
# Epoch 26/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.0575 - acc: 0.1540
# Epoch 27/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0433 - acc: 0.1306
# Epoch 28/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0406 - acc: 0.1399
# Epoch 29/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0410 - acc: 0.1319
# Epoch 30/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0399 - acc: 0.1418
# Epoch 31/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.0391 - acc: 0.1246
# Epoch 32/60
# 1770/1770 [==============================] - 81s 45ms/step - loss: 0.0394 - acc: 0.1282
# Epoch 33/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0374 - acc: 0.1409
# Epoch 34/60
# 1770/1770 [==============================] - 81s 45ms/step - loss: 0.0373 - acc: 0.1382
# Epoch 35/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0377 - acc: 0.1323
# Epoch 36/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0364 - acc: 0.1218
# Epoch 37/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0390 - acc: 0.1325
# Epoch 38/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.0621 - acc: 0.1320
# Epoch 39/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.0413 - acc: 0.1300
# Epoch 40/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.0380 - acc: 0.1172
# Epoch 41/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.0372 - acc: 0.1207
# Epoch 42/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0381 - acc: 0.1401
# Epoch 43/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.0348 - acc: 0.1192
# Epoch 44/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.0333 - acc: 0.1171
# Epoch 45/60
# 1770/1770 [==============================] - 81s 45ms/step - loss: 0.0345 - acc: 0.1359
# Epoch 46/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.0336 - acc: 0.1507
# Epoch 47/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0335 - acc: 0.1545
# Epoch 48/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0322 - acc: 0.1560
# Epoch 49/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.0311 - acc: 0.1457
# Epoch 50/60
# 1770/1770 [==============================] - 81s 45ms/step - loss: 0.0376 - acc: 0.1412
# Epoch 51/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.0359 - acc: 0.1406
# Epoch 52/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0354 - acc: 0.1366
# Epoch 53/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0378 - acc: 0.1300
# Epoch 54/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.0389 - acc: 0.1205
# Epoch 55/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.0322 - acc: 0.1195
# Epoch 56/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0300 - acc: 0.1226
# Epoch 57/60
# 1770/1770 [==============================] - 81s 45ms/step - loss: 0.0296 - acc: 0.1161
# Epoch 58/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0295 - acc: 0.1158
# Epoch 59/60
# 1770/1770 [==============================] - 81s 46ms/step - loss: 0.0330 - acc: 0.1138
# Epoch 60/60
# 1770/1770 [==============================] - 80s 45ms/step - loss: 0.0338 - acc: 0.1337

# %%
plt.title("Metrics")
plt.plot(results.history["loss"], label="loss")
plt.xlabel("Epochs")
plt.legend()

# %%
result = model.predict(inputs[100].reshape(1, 256, 512, 1))
plt.imshow(inputs[100].reshape(256, 512), cmap=plt.cm.bone)
plt.show()
for x in range(9):
    plt.imshow(result[0][:, :, x])
    plt.show()
