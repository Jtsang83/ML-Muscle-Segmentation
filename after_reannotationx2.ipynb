# %%
import matplotlib.pyplot as plt
import numpy as np
import SimpleITK as sitk
import os as os
import nrrd as reader

# %%
def join(one, two):
    return os.path.join(one, two)

# %%
def check_path(path):
    count=0
    for files in sorted(os.listdir(path)):
        image_path = os.path.join(path,files)
        count+=1
    return count

# %%
# (patient count* 15) check_path function will return total patient count 
folder_path = join(os.getcwd(), "Incoming Annotations")

length = check_path(folder_path)
inputs = np.zeros((length*15,256,512, 1))
outputs = np.zeros((length*15,256,512 , 9))

# %%
def dcm_to_np(path):
    global dic_count
    try:
        slice_filenames = sitk.ImageSeriesReader_GetGDCMSeriesFileNames(path)
        image = sitk.ReadImage(slice_filenames)
        for x in range(15):
            current_slice = image[:, :, x]
            current_array = sitk.GetArrayFromImage(current_slice)
            inputs[dic_count] = current_array[:, :, np.newaxis]
            dic_count+=1
        print(dic_count)
    except Exception as e:
        print(e)
#         print("Problem with this folder -> " + path)

# %%
def nrrd_to_np(meta_object):
    global ann_count
    try:
        data = sitk.GetArrayFromImage(meta_object)
        for p in range(15):
            current_seg = data[p, :, :]
            black = np.zeros([256, 512, 9])
            for y, a in enumerate(current_seg):
                for x, b in enumerate(a):
                    if b>0:
                        black[y][x][b-1] = 1
            outputs[ann_count] = black
            ann_count+=1
        print(ann_count)
    except Exception as e:
        print(e)

# %%
dic_count = 0
ann_count = 0

try:
    for patient in sorted(os.listdir(folder_path)):
            patient_path = join(folder_path, patient)
            nrrd_folder = join(patient_path, "NRRD")
            dcm_to_np(patient_path)
            for nrrd in os.listdir(nrrd_folder):
                if(".nrrd" in nrrd):
                    segmentation = sitk.ReadImage(join(nrrd_folder, nrrd))
                    nrrd_to_np(segmentation)
except Exception as e:
    print(e)
# Out:
# 15
# 15
# 30
# 30
# 45
# 45
# 60
# 60
# 75
# 75
# 90
# 90
# 105
# 105
# 120
# 120
# 135
# 135
# 150
# 150
# 165
# 165
# 180
# 180
# 195
# 195
# 210
# 210
# 225
# 225
# 240
# 240
# 255
# 255
# 270
# 270
# 285
# 285
# 300
# 300
# 315
# 315
# 330
# 330
# 345
# 345
# 360
# 360
# 375
# 375
# 390
# 390
# 405
# 405
# 420
# 420
# 435
# 435
# 450
# 450
# 465
# 465
# 480
# 480
# 495
# 495
# 510
# 510
# 525
# 525
# 540
# 540
# 555
# 555
# 570
# 570
# 585
# 585
# 600
# 600
# 615
# 615
# 630
# 630
# 645
# 645
# 660
# 660
# 675
# 675
# 690
# 690
# 705
# 705
# 720
# 720
# 735
# 735
# 750
# 750
# 765
# 765
# 780
# 780
# 795
# 795
# 810
# 810
# 825
# 825
# 840
# 840

# %%
for i in range(1500, 1515):
    plt.imshow(inputs[i].reshape(256, 512), cmap=plt.cm.bone)
    plt.imshow(outputs[i][:, :, 2], alpha=0.5)
    plt.show()

# %%
import sklearn.preprocessing as sk
scaler = sk.MinMaxScaler(feature_range=(0, 255))
inputs = scaler.fit_transform(inputs.flatten().reshape(-1, 1))

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *

def unet_model(im_height, im_width, im_chan):

    input_img = Input((im_height, im_width, im_chan,), name='img')

    inp = BatchNormalization()(input_img)

    c1 = Conv2D(4, (3, 3), activation='relu', padding='same') (inp)
    a1 = MaxPooling2D((2, 2))(c1)
    c1 = Dropout(0.2)(c1)
    c1 = Conv2D(4, (3, 3), activation='relu', padding='same') (c1)
    p1 = MaxPooling2D((2, 2)) (c1)

    cat1 = concatenate([p1, a1])

    c2 = Conv2D(8, (3, 3), activation='relu', padding='same') (cat1)
    a2 = MaxPooling2D((2, 2))(c2)
    c2 = Dropout(0.2)(c2)
    c2 = Conv2D(8, (3, 3), activation='relu', padding='same') (c2)
    p2 = MaxPooling2D((2, 2)) (c2)

    cat2 = concatenate([p2, a2])

    c3 = Conv2D(16, (3, 3), activation='relu', padding='same') (cat2)
    a3 = MaxPooling2D((2, 2))(c3)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(16, (3, 3), activation='relu', padding='same') (c3)
    p3 = MaxPooling2D((2, 2)) (c3)

    cat3 = concatenate([p3, a3])

    c4 = Conv2D(32, (3, 3), activation='relu', padding='same') (cat3)
    a4 = MaxPooling2D((2, 2))(c4)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(32, (3, 3), activation='relu', padding='same') (c4)
    p4 = MaxPooling2D((2, 2)) (c4)

    cat4 = concatenate([p4, a4])

    c5 = Conv2D(64, (3, 3), activation='relu', padding='same') (cat4)
    a5 = MaxPooling2D((2, 2))(c5)
    c5 = Dropout(0.2)(c5)
    c5 = Conv2D(64, (3, 3), activation='relu', padding='same') (c5)
    p5 = MaxPooling2D((2, 2)) (c5)

    cat5 = concatenate([p5, a5])

    c6 = Conv2D(128, (3, 3), activation='relu', padding='same') (cat5)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same') (c6)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c5])
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same') (u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same') (c7)

    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c4])
    c8 = Conv2D(32, (3, 3), activation='relu', padding='same') (u8)
    c8 = Dropout(0.2)(c8)
    c8 = Conv2D(32, (3, 3), activation='relu', padding='same') (c8)

    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c3])
    c9 = Conv2D(16, (3, 3), activation='relu', padding='same') (u9)
    c9 = Dropout(0.2)(c9)
    c9 = Conv2D(16, (3, 3), activation='relu', padding='same') (c9)

    u10 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same') (c9)
    u10 = concatenate([u10, c2])
    c10 = Conv2D(8, (3, 3), activation='relu', padding='same') (u10)
    c10 = Dropout(0.2)(c10)
    c10 = Conv2D(8, (3, 3), activation='relu', padding='same') (c10)

    u11 = Conv2DTranspose(4, (2, 2), strides=(2, 2), padding='same') (c10)
    u11 = concatenate([u11, c1], axis = 3)
    c11 = Conv2D(4, (3, 3), activation='relu', padding='same') (u11)
    c11 = Dropout(0.2)(c11)
    c11 = Conv2D(4, (3, 3), activation='relu', padding='same') (c11)

    outputs = Conv2D(9, (1, 1), activation='sigmoid') (c11)

    model = Model(inputs=[input_img], outputs=[outputs])

    return model
model = unet_model(256, 512, 1)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                [(None, 256, 512, 1) 0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 512, 1)  4           img[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 512, 4)  40          batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256, 512, 4)  0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 512, 4)  148         dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 256, 4)  0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 256, 4)  0           conv2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 128, 256, 8)  0           max_pooling2d_1[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 256, 8)  584         concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128, 256, 8)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 256, 8)  584         dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 64, 128, 8)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 128, 8)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 128, 16)  0           max_pooling2d_3[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 128, 16)  2320        concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64, 128, 16)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 128, 16)  2320        dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 32, 64, 16)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 32, 64, 16)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 64, 32)   0           max_pooling2d_5[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 64, 32)   9248        concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32, 64, 32)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 64, 32)   9248        dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 16, 32, 32)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 16, 32, 32)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 32, 64)   0           max_pooling2d_7[0][0]
#                                                                  max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 32, 64)   36928       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16, 32, 64)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 32, 64)   36928       dropout_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 8, 16, 64)    0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 8, 16, 64)    0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 8, 16, 128)   0           max_pooling2d_9[0][0]
#                                                                  max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 16, 128)   147584      concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 8, 16, 128)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 16, 128)   147584      dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 32, 64)   32832       conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 16, 32, 128)  0           conv2d_transpose[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 32, 64)   73792       concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 32, 64)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 32, 64)   36928       dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 64, 32)   8224        conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 32, 64, 64)   0           conv2d_transpose_1[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 64, 32)   18464       concatenate_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 32, 64, 32)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 64, 32)   9248        dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 128, 16)  2064        conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 64, 128, 32)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 128, 16)  4624        concatenate_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 64, 128, 16)  0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 128, 16)  2320        dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 256, 8)  520         conv2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 128, 256, 16) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 256, 8)  1160        concatenate_8[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 128, 256, 8)  0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 256, 8)  584         dropout_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 256, 512, 4)  132         conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 256, 512, 8)  0           conv2d_transpose_4[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 512, 4)  292         concatenate_9[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 256, 512, 4)  0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 512, 4)  148         dropout_10[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 512, 9)  45          conv2d_21[0][0]
# ==================================================================================================
# Total params: 584,897
# Trainable params: 584,895
# Non-trainable params: 2
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=["binary_crossentropy"])
results = model.fit(x=inputs, y=outputs, epochs=60, batch_size=8)

# %%
plt.title("Metrics")
plt.plot(results.history["loss"], label="loss")
plt.xlabel("Epochs")
plt.legend()

# %%
result = model.predict(inputs[100].reshape(1, 256, 512, 1))
plt.imshow(inputs[100].reshape(256, 512), cmap=plt.cm.bone)
plt.show()
plt.imshow(result[0][:, :, 3])
plt.show()
